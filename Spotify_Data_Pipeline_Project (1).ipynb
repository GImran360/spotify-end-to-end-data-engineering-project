# %%
pip install spotify
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 kB 2.5 MB/s eta 0:00:00
# ...

# %%
pip install instagram
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.8/144.8 kB 3.1 MB/s eta 0:00:00
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-9c7d2dba78fb> in <cell line: 0>()
# ----> 1 import spotipy
#       2 from spotipy.oauth2 import SpotifyClientCredentials
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'spotipy'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install spotipy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.5/261.5 kB 18.7 MB/s eta 0:00:00
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
#add your keys here
client_credentials_manager = SpotifyClientCredentials(client_id="87bfa84060e2431fadbe62e23c107f09", client_secret="5e45bb737b8749c0b69b1c214a3f06af")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
Fplaylist_link="https://open.spotify.com/playlist/54ZA9LXFvvFujmOVWXpHga"
#playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f"
#https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f&nd=1

# %%
playlist_URI = playlist_link.split("/")[-1].split('?')[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-b5ea833ae33a> in <cell line: 0>()
# ----> 1 playlist_URI = playlist_link.split("/")[-1].split('?')[0]
#
# NameError: name 'playlist_link' is not defined

# %%
playlist_URI='54ZA9LXFvvFujmOVWXpHga'

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data['items'][0]['track']['album']['id']
# Out:
# '5EVlXlHbRQI8ybuNt4ArXI'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'After the Gold Rush (2009 Remaster)'

# %%
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/54ZA9LXFvvFujmOVWXpHga/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2021-10-23T17:55:57Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/amandaemcee'},
#     'href': 'https://api.spotify.com/v1/users/amandaemcee',
#     'id': 'amandaemcee',
#     'type': 'user',
#     'uri': 'spotify:user:amandaemcee'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
# ...

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 11

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '1970-08-31'

# %%
data['items'][0]['track']['album']['images']
# Out:
# [{'height': 640,
#   'url': 'https://i.scdn.co/image/ab67616d0000b273a2507ac7f34640ac11b3f31b',
#   'width': 640},
#  {'height': 300,
#   'url': 'https://i.scdn.co/image/ab67616d00001e02a2507ac7f34640ac11b3f31b',
#   'width': 300},
#  {'height': 64,
#   'url': 'https://i.scdn.co/image/ab67616d00004851a2507ac7f34640ac11b3f31b',
#   'width': 64}]

# %%
data['items'][0]['track']['album']['href']
# Out:
# 'https://api.spotify.com/v1/albums/5EVlXlHbRQI8ybuNt4ArXI'

# %%
data['items'][0]['track']['album']['available_markets'].count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-2cc05d3292ba> in <cell line: 0>()
# ----> 1 data['items'][0]['track']['album']['available_markets'].count()
#
# TypeError: list.count() takes exactly one argument (0 given)

# %%
len(data['items'][0]['track']['album']['available_markets'])
# Out:
# 184

# %%
'IN' in data['items'][0]['track']['album']['available_markets']
# Out:
# True

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/5EVlXlHbRQI8ybuNt4ArXI'

# %%
album_list=[]
for row in data['items']:
   album_id=row['track']['album']['id']
   album_name=row['track']['album']['name']
   album_release_date=row['track']['album']['release_date']
   album_total_tracks=row['track']['album']['total_tracks']
   album_url=row['track']['album']['external_urls']['spotify']
 #  album_popularity=row['track']['album']['popularity]
   album_available_markets=len(row['track']['album']['available_markets'])
   album_images=row['track']['album']['images']

   album_elements={'album_id':album_id,'album_name':album_name,'album_images':album_images,'album_release_date':album_release_date,'album_total_tracks':album_total_tracks,'album_url':album_url,'album_available_markets':album_available_markets}
   album_list.append(album_elements)

# %%
album_list
# Out:
# [{'album_id': '5EVlXlHbRQI8ybuNt4ArXI',
#   'album_name': 'After the Gold Rush (2009 Remaster)',
#   'album_images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273a2507ac7f34640ac11b3f31b',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02a2507ac7f34640ac11b3f31b',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851a2507ac7f34640ac11b3f31b',
#     'width': 64}],
#   'album_release_date': '1970-08-31',
#   'album_total_tracks': 11,
#   'album_url': 'https://open.spotify.com/album/5EVlXlHbRQI8ybuNt4ArXI',
#   'album_available_markets': 184},
#  {'album_id': '2ar6Yxkh6psvQOrGqk248v',
#   'album_name': 'Only One',
#   'album_images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273f2209e63affaa48af1b0a3b5',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02f2209e63affaa48af1b0a3b5',
#     'width': 300},
# ...

# %%
album_df=pd.DataFrame.from_dict(album_list)

# %%
album_df
# Out:
#                   album_id                                         album_name  \
# 0   5EVlXlHbRQI8ybuNt4ArXI                After the Gold Rush (2009 Remaster)
# 1   2ar6Yxkh6psvQOrGqk248v                                           Only One
# 2   524iOqgCw66tGwZLYKDiqm                  Bruckner: Mass in E Minor, Motets
# 3   1NFGnxmeIEBakre4DvLaJq                                              Plans
# 4   7JG0QwvJRzPILHEW1xHEJj                       Amélie (Original Soundtrack)
# ..                     ...                                                ...
# 95  4qYc8tWiSQveNrhAjJjpxW                                    Relaxing Chopin
# 96  1sIKjNKPo058xiSZGm5wlm  Copland: Appalachian Spring, Rodeo, Billy the ...
# 97  4Ll3RGpn0eVY6MMKPTP99C  Debussy: Suite bergamasque, L. 75, 3. Clair de...
# 98  7d5MLT2L4TYnaMZTzaWnDo                                    Debussy at Dawn
# 99  3I5pDWA3WvlHbvkZDos5kG  Daniel Barenboim Conducts Works by Ravel, Debu...
#
# ...

# %%
album_images=row['track']['album']['images']

# %%
album_images
# Out:
# [{'height': 640,
#   'url': 'https://i.scdn.co/image/ab67616d0000b2734a3d9e5c86fa4350295c850b',
#   'width': 640},
#  {'height': 300,
#   'url': 'https://i.scdn.co/image/ab67616d00001e024a3d9e5c86fa4350295c850b',
#   'width': 300},
#  {'height': 64,
#   'url': 'https://i.scdn.co/image/ab67616d000048514a3d9e5c86fa4350295c850b',
#   'width': 64}]

# %%
data['items'][0]['track']['album']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6v8FB84lnmJs434UJf2Mrm'},
#   'href': 'https://api.spotify.com/v1/artists/6v8FB84lnmJs434UJf2Mrm',
#   'id': '6v8FB84lnmJs434UJf2Mrm',
#   'name': 'Neil Young',
#   'type': 'artist',
#   'uri': 'spotify:artist:6v8FB84lnmJs434UJf2Mrm'}]

# %%
data['items'][0]['track']['album']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6v8FB84lnmJs434UJf2Mrm'},
#   'href': 'https://api.spotify.com/v1/artists/6v8FB84lnmJs434UJf2Mrm',
#   'id': '6v8FB84lnmJs434UJf2Mrm',
#   'name': 'Neil Young',
#   'type': 'artist',
#   'uri': 'spotify:artist:6v8FB84lnmJs434UJf2Mrm'}]

# %%
artist_list=[]
for row in data['items']:
  for key,value in row.items():
    if key=='track':
      for artist in value['artists']:
        artist_dict={'artist_id':artist['id'],'artist_name':artist['name'],'external_urls':artist['href'],'artist_type':artist['type'],'artist_uri':artist['uri'],'artist_type':artist['type']}
        artist_list.append(artist_dict)

# %%
artist_df=pd.DataFrame.from_dict(artist_list)

# %%
artist_df
# Out:
#                   artist_id                         artist_name  \
# 0    6v8FB84lnmJs434UJf2Mrm                          Neil Young
# 1    5K4W6rqBFWDnAN6FQUkS6x                          Kanye West
# 2    4STHEaNw4mPZ2tzheohgXB                      Paul McCartney
# 3    2bM3j1JQWBkmzuoZKu4zj2                      Anton Bruckner
# 4    0f3PsS9IQ6whvNMFFKnpjl  Choir of King's College, Cambridge
# ..                      ...                                 ...
# 265  0d6alfZHUx3xoRnPjkTL7Q                      Alice Sara Ott
# 266  1Uff91EOsvd99rtAupatMP                      Claude Debussy
# 267  5Gi9bw3svtZMwonzcQG2wm                       Zoltán Kocsis
# 268  1Uff91EOsvd99rtAupatMP                      Claude Debussy
# 269  78sEozQOEJxzXegUuqRSgH                    Daniel Barenboim
#
#                                          external_urls artist_type  \
# 0    https://api.spotify.com/v1/artists/6v8FB84lnmJ...      artist
# ...

# %%
df = pd.DataFrame.from_dict(data)

# %%
df
# Out:
#                                                  href  \
# 0   https://api.spotify.com/v1/playlists/54ZA9LXFv...
# 1   https://api.spotify.com/v1/playlists/54ZA9LXFv...
# 2   https://api.spotify.com/v1/playlists/54ZA9LXFv...
# 3   https://api.spotify.com/v1/playlists/54ZA9LXFv...
# 4   https://api.spotify.com/v1/playlists/54ZA9LXFv...
# ..                                                ...
# 95  https://api.spotify.com/v1/playlists/54ZA9LXFv...
# 96  https://api.spotify.com/v1/playlists/54ZA9LXFv...
# 97  https://api.spotify.com/v1/playlists/54ZA9LXFv...
# 98  https://api.spotify.com/v1/playlists/54ZA9LXFv...
# 99  https://api.spotify.com/v1/playlists/54ZA9LXFv...
#
#                                                 items  limit  \
# 0   {'added_at': '2021-10-23T17:55:57Z', 'added_by...    100
# 1   {'added_at': '2021-10-23T17:55:57Z', 'added_by...    100
# 2   {'added_at': '2021-10-23T17:55:57Z', 'added_by...    100
# 3   {'added_at': '2021-10-23T17:55:57Z', 'added_by...    100
# ...

# %%
df.describe()
# Out:
#        limit  offset  total
# count  100.0   100.0  100.0
# mean   100.0     0.0  715.0
# std      0.0     0.0    0.0
# min    100.0     0.0  715.0
# 25%    100.0     0.0  715.0
# 50%    100.0     0.0  715.0
# 75%    100.0     0.0  715.0
# max    100.0     0.0  715.0

# %%
df.values
# Out:
# array([['https://api.spotify.com/v1/playlists/54ZA9LXFvvFujmOVWXpHga/tracks?offset=0&limit=100&additional_types=track',
# ...

# %%
df.columns
# Out:
# Index(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   href      100 non-null    object
#  1   items     100 non-null    object
#  2   limit     100 non-null    int64
#  3   next      100 non-null    object
#  4   offset    100 non-null    int64
#  5   previous  0 non-null      object
#  6   total     100 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 5.6+ KB

# %%
print(df.info())
print(df.describe())
print(df.shape)
print(df.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   href      100 non-null    object
#  1   items     100 non-null    object
#  2   limit     100 non-null    int64
#  3   next      100 non-null    object
#  4   offset    100 non-null    int64
#  5   previous  0 non-null      object
#  6   total     100 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 5.6+ KB
# None
#        limit  offset  total
# count  100.0   100.0  100.0
# mean   100.0     0.0  715.0
# std      0.0     0.0    0.0
# min    100.0     0.0  715.0
# 25%    100.0     0.0  715.0
# 50%    100.0     0.0  715.0
# 75%    100.0     0.0  715.0
# max    100.0     0.0  715.0
# (100, 7)
# Index(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'], dtype='object')

# %%
song_list=[]
for row in data['items']:
   song_id=row['track']['id']
   song_name=row['track']['name']
   song_duration=row['track']['duration_ms']
   song_url=row['track']['external_urls']['spotify']
   song_popularity=row['track']['popularity']
   song_added=row['added_at']
   album_id=row['track']['album']['id']
   artist_id=row['track']['album']['artists'][0]['id']
   song_elements={'song_id':song_id,'song_name':song_name,'song_duration':song_duration,'song_url':song_url,'song_popularity':song_popularity,'song_added':song_added,'album_id':album_id,'artist_id':artist_id}
   song_list.append(song_elements)

# %%
song_list
# Out:
# [{'song_id': '4nRhbx8L4ifnMKaE5jSQGR',
#   'song_name': 'Only Love Can Break Your Heart',
#   'song_duration': 188600,
#   'song_url': 'https://open.spotify.com/track/4nRhbx8L4ifnMKaE5jSQGR',
#   'song_popularity': 53,
#   'song_added': '2021-10-23T17:55:57Z',
#   'album_id': '5EVlXlHbRQI8ybuNt4ArXI',
#   'artist_id': '6v8FB84lnmJs434UJf2Mrm'},
#  {'song_id': '0j35X8cTq543QDYLOyqB8W',
#   'song_name': 'Only One',
#   'song_duration': 280226,
#   'song_url': 'https://open.spotify.com/track/0j35X8cTq543QDYLOyqB8W',
#   'song_popularity': 51,
#   'song_added': '2021-10-23T17:55:57Z',
#   'album_id': '2ar6Yxkh6psvQOrGqk248v',
#   'artist_id': '5K4W6rqBFWDnAN6FQUkS6x'},
#  {'song_id': '5vJaDPHpkVAXetkF8YD88S',
#   'song_name': 'Ave Maria, WAB 6',
#   'song_duration': 184773,
#   'song_url': 'https://open.spotify.com/track/5vJaDPHpkVAXetkF8YD88S',
#   'song_popularity': 9,
#   'song_added': '2021-10-23T17:55:57Z',
#   'album_id': '524iOqgCw66tGwZLYKDiqm',
# ...

# %%
song_df=pd.DataFrame.from_dict(song_list)

# %%
song_df
# Out:
#                    song_id                                          song_name  \
# 0   4nRhbx8L4ifnMKaE5jSQGR                     Only Love Can Break Your Heart
# 1   0j35X8cTq543QDYLOyqB8W                                           Only One
# 2   5vJaDPHpkVAXetkF8YD88S                                   Ave Maria, WAB 6
# 3   2Wc6WJFIh86EDnlMxIKhv8                          Someday You Will Be Loved
# 4   6FRQ4HYndOhM4OlVt0Ou3L                                          Le moulin
# ..                     ...                                                ...
# 95  2h3W08zq4Ub276rCG40Wg5            Prelude No. 4 in E Minor, Op. 28, No. 4
# 96  6vS8JCT9WqTFeAuu8smjRF          Appalachian Spring: VII. Doppio movimento
# 97  1cmigB9I6IRpFqjIbzvSQB       Suite bergamasque, L. 75: III. Clair de lune
# 98  6X5TOSckOqubhqy8zbioNR  Images oubliées, CD 94: II. Sarabande. Souveni...
# 99  02fv3KjMxZCUBkrWWPUsBo  Prelude to the Afternoon of a Faun, L. 86 - Re...
#
# ...

# %%
album_df=album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df=artist_df.drop_duplicates(subset=['artist_id'])

# %%
song_df=song_df.drop_duplicates(subset=['song_id'])

# %%
album_df.head()
# Out:
#                  album_id                           album_name  \
# 0  5EVlXlHbRQI8ybuNt4ArXI  After the Gold Rush (2009 Remaster)
# 1  2ar6Yxkh6psvQOrGqk248v                             Only One
# 2  524iOqgCw66tGwZLYKDiqm    Bruckner: Mass in E Minor, Motets
# 3  1NFGnxmeIEBakre4DvLaJq                                Plans
# 4  7JG0QwvJRzPILHEW1xHEJj         Amélie (Original Soundtrack)
#
#                                         album_images album_release_date  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...         1970-08-31
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...         2015-01-08
# 2  [{'height': 640, 'url': 'https://i.scdn.co/ima...         2020-10-16
# 3  [{'height': 640, 'url': 'https://i.scdn.co/ima...         2005-08-29
# 4  [{'height': 640, 'url': 'https://i.scdn.co/ima...         2001-04-23
#
#    album_total_tracks                                          album_url  \
# 0                  11  https://open.spotify.com/album/5EVlXlHbRQI8ybu...
# ...

# %%
album_df['album_release_date']=pd.to_datetime(album_df['album_release_date'],errors='coerce', format='mixed')
# Out:
# <ipython-input-121-fbeacbdbed0e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   album_df['album_release_date']=pd.to_datetime(album_df['album_release_date'],errors='coerce', format='mixed')

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 94 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   album_id                 94 non-null     object
#  1   album_name               94 non-null     object
#  2   album_images             94 non-null     object
#  3   album_release_date       94 non-null     datetime64[ns]
#  4   album_total_tracks       94 non-null     int64
#  5   album_url                94 non-null     object
#  6   album_available_markets  94 non-null     int64
# dtypes: datetime64[ns](1), int64(2), object(4)
# memory usage: 5.9+ KB

# %%
artist_df.head()
# Out:
#                 artist_id                         artist_name  \
# 0  6v8FB84lnmJs434UJf2Mrm                          Neil Young
# 1  5K4W6rqBFWDnAN6FQUkS6x                          Kanye West
# 2  4STHEaNw4mPZ2tzheohgXB                      Paul McCartney
# 3  2bM3j1JQWBkmzuoZKu4zj2                      Anton Bruckner
# 4  0f3PsS9IQ6whvNMFFKnpjl  Choir of King's College, Cambridge
#
#                                        external_urls artist_type  \
# 0  https://api.spotify.com/v1/artists/6v8FB84lnmJ...      artist
# 1  https://api.spotify.com/v1/artists/5K4W6rqBFWD...      artist
# 2  https://api.spotify.com/v1/artists/4STHEaNw4mP...      artist
# 3  https://api.spotify.com/v1/artists/2bM3j1JQWBk...      artist
# 4  https://api.spotify.com/v1/artists/0f3PsS9IQ6w...      artist
#
#                               artist_uri
# 0  spotify:artist:6v8FB84lnmJs434UJf2Mrm
# 1  spotify:artist:5K4W6rqBFWDnAN6FQUkS6x
# 2  spotify:artist:4STHEaNw4mPZ2tzheohgXB
# ...

# %%
song_df.head()
# Out:
#                   song_id                       song_name  song_duration  \
# 0  4nRhbx8L4ifnMKaE5jSQGR  Only Love Can Break Your Heart         188600
# 1  0j35X8cTq543QDYLOyqB8W                        Only One         280226
# 2  5vJaDPHpkVAXetkF8YD88S                Ave Maria, WAB 6         184773
# 3  2Wc6WJFIh86EDnlMxIKhv8       Someday You Will Be Loved         191373
# 4  6FRQ4HYndOhM4OlVt0Ou3L                       Le moulin         267733
#
#                                             song_url  song_popularity  \
# 0  https://open.spotify.com/track/4nRhbx8L4ifnMKa...               53
# 1  https://open.spotify.com/track/0j35X8cTq543QDY...               51
# 2  https://open.spotify.com/track/5vJaDPHpkVAXetk...                9
# 3  https://open.spotify.com/track/2Wc6WJFIh86EDnl...               36
# 4  https://open.spotify.com/track/6FRQ4HYndOhM4Ol...                0
#
#              song_added                album_id               artist_id
# ...

# %%
song_df['song_added']=pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   song_id          100 non-null    object
#  1   song_name        100 non-null    object
#  2   song_duration    100 non-null    int64
#  3   song_url         100 non-null    object
#  4   song_popularity  100 non-null    int64
#  5   song_added       100 non-null    datetime64[ns, UTC]
#  6   album_id         100 non-null    object
#  7   artist_id        100 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 6.4+ KB
